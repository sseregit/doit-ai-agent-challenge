# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key=os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
response = client.audio.speech.create(
    model="tts-1-hd",
    voice="alloy",
    input="Hello world! This is a TTS test",
)

response.write_to_file("Hello_world.mp3")

import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
voice = "ash"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model="tts-1-hd",
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test.",
)

response.write_to_file(mp3_file)

import IPython.display as ipd

ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

with open('../data/images/image_quiz_eng.json', 'r', encoding='utf-8') as f:
  eng_dict = json.load(f)

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) The display case shows a variety of round breads.\n- (2) Many of the breads are dusted with flour.\n- (3) There are workers behind the counter wearing white caps.\n- (4) There is a person standing at the front wearing a red shirt.',
#   'img': 'mangwon_bakery.jpg'},
#  {'no': 2,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) It shows many people sitting at long rows of tables using laptops.\n- (2) There is a large screen on the stage with a presentation in progress.\n- (3) The interior lighting is dim, creating a calm atmosphere.\n- (4) Purple banners are hanging on the wall, with the text “DIVE 2024 IN BUSAN.”',
#   'img': 'busan_dive.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage', 'shim-mer']

for q in eng_dict:
  no = q['no']
  quiz = q['eng']
  quiz = quiz.replace('- (1)', '- One.\t')
  quiz = quiz.replace('- (2)', '- Two.\t')
  quiz = quiz.replace('- (3)', '- Three.\t')
  quiz = quiz.replace('- (4)', '- Four.\t')

  print(no, quiz)

  voice = voices[no % len(voices)]

  response = client.audio.speech.create(
      model='tts-1-hd',
      voice=voice,
      input=f'#{no}. {quiz}',
  )

  response.write_to_file(f"../data/audio/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 The display case shows a variety of round breads.
# - Two.	 Many of the breads are dusted with flour.
# - Three.	 There are workers behind the counter wearing white caps.
# - Four.	 There is a person standing at the front wearing a red shirt.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 It shows many people sitting at long rows of tables using laptops.
# - Two.	 There is a large screen on the stage with a presentation in progress.
# - Three.	 The interior lighting is dim, creating a calm atmosphere.
# - Four.	 Purple banners are hanging on the wall, with the text “DIVE 2024 IN BUSAN.”

# %%
ipd.Audio(f"../data/audio/1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
